# %%
from dotenv import load_dotenv,find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
import xmltodict
import requests
from bs4 import BeautifulSoup
from langchain.text_splitter import CharacterTextSplitter,RecursiveCharacterTextSplitter
from langchain.docstore.document import Document
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.llms import OpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
import os
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory, ConversationSummaryBufferMemory
from langchain.chains import RetrievalQAWithSourcesChain,VectorDBQAWithSourcesChain,ConversationalRetrievalChain

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}

# %%
def extract_text_from(url):
    html = requests.get(url,headers= headers).text
    soup = BeautifulSoup(html, features="html.parser")
    text = soup.get_text()

    lines = (line.strip() for line in text.splitlines())
    return '\n'.join(line for line in lines if line)

# %%
r = requests.get("https://vetic.in/sitemap.xml",headers= headers)
xml = r.text
raw = xmltodict.parse(xml)
print(raw)
site_urls = []

for item in raw['sitemapindex']['sitemap']:
    site_urls.append(item['loc'])

site_urls
# Out:
# {'sitemapindex': {'@xmlns': 'http://www.sitemaps.org/schemas/sitemap/0.9', 'sitemap': [{'loc': 'https://vetic.in/sitemap_website.xml'}, {'loc': 'https://vetic.in/sitemap_dynamic.xml'}, {'loc': 'https://vetic.in/sitemap_blogs.xml'}]}}
# ['https://vetic.in/sitemap_website.xml',
#  'https://vetic.in/sitemap_dynamic.xml',
#  'https://vetic.in/sitemap_blogs.xml']

# %%
pages = []

for site_url in site_urls:
    try:
        r = requests.get(site_url,headers= headers)
        xml = r.text
        raw = xmltodict.parse(xml)
        print(raw)
        for info in raw['urlset']['url']:
            url = info['loc']
            pages.append({'text': extract_text_from(url), 'source': url})
    except:
        print("Error")
# Out:
# {'urlset': {'@xmlns': 'http://www.sitemaps.org/schemas/sitemap/0.9', '@xmlns:image': 'http://www.google.com/schemas/sitemap-image/1.1', 'url': [{'loc': 'https://vetic.in/', 'lastmod': '2022-08-06T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/gurgaon/sector-57', 'lastmod': '2022-11-10T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/gurgaon', 'lastmod': '2022-11-10T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/gurgaon/golf-course-road', 'lastmod': '2022-11-10T11:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/gurgaon/sector-45', 'lastmod': '2023-01-10T11:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/gurgaon/sohna-road', 'lastmod': '2023-02-10T11:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/noida/sector-49', 'lastmod': '2023-01-10T11:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/clinics/delhi/sector-11', 'lastmod': '2022-11-10T110:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/our-services', 'lastmod': '2022-08-06T11:50:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/urgent-care', 'lastmod': '2022-08-06T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/preventive-care', 'lastmod': '2022-08-06T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/veterinary-consultation', 'lastmod': '2022-08-06T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/about-us', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/page-not-found', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/terms-of-service', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/privacy-policy', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/grooming', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/vaccination', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-surgery-clinic-gurgaon', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/noida/dog-surgery-clinic-noida', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/at-home-vet-services', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/noida/grooming', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/noida/vaccination', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/noida/at-home-vet-services', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/veterinary-hospital-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/vet-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/vet-hospital-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/pet-doctor-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/dog-hospital-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/veterinarian-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/vet-doctor-near-me', 'lastmod': '2023-02-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/pet-clinic-near-me', 'lastmod': '2022-12-09T16:20:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/dog-clinic-near-me', 'lastmod': '2022-12-09T16:20:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/near-me/pet-hospital-near-me', 'lastmod': '2023-02- ...
# {'urlset': {'@xmlns': 'http://www.sitemaps.org/schemas/sitemap/0.9', 'url': [{'loc': 'https://vetic.in/Dr.-Vikas-Sharma', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr.-Nitish-Mishra', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-home-services-ghaziabad', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-emergency-care-ghaziabad', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-diagnostics-ghaziabad', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr-Sahil-Nandal', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/veterinary-doctor-ghaziabad', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-hospital-ghaziabad', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr.-Vaibhav-Bishnoi', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr.-Raghubir-Singh-Mehla', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr.-Parvinder-Singh', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/DR.-HAMID', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/Dr.-Abhishek-Mahajan', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-vaccination-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/animal-hospital-delhi', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-hospital-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/emergency-pet-hospital-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/vet-doctor-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-clinic-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-vaccination-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-clinic-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-clinic-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-hospital-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/veterinary-clinic-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/veterinary-hospital-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-hospital-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/vet-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-hospital-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-surgeries-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/cat-grooming-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-grooming-near-me', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/pet-surgeries-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-grooming-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-doctor-gurgaon', 'lastmod': '2023-05-28T12:32:47.839Z', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/dog-consultation-near-me', 'lastmod ...
# {'urlset': {'@xmlns': 'http://www.sitemaps.org/schemas/sitemap/0.9', '@xmlns:image': 'http://www.google.com/schemas/sitemap-image/1.1', 'url': [{'loc': 'https://vetic.in/blog/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/pet-health/healthy-body-weight-importance-in-pets/', 'lastmod': '2022-08-06T17:15:49+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/pet-parents/a-guide-for-new-pet-parents/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/pet-care/pet-grooming-tips-and-tricks-to-keep-your-pet-cool-and-clean-in-the-summer-heat/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/pet-care/worried-about-grooming-your-dog-get-it-done-in-7-simple-steps/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/tag/dogs/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/tag/cats/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/tag/pets/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/tag/grooming/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/category/pet-parents/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/category/pet-health/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/category/pet-care/', 'lastmod': '2022-05-26T14:50:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/contact-me/', 'lastmod': '2022-12-19T16:20:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/social-icons/', 'lastmod': '2022-12-19T16:20:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/galleries/', 'lastmod': '2022-12-19T16:20:29+05:30', 'changefreq': 'weekly'}, {'loc': 'https://vetic.in/blog/home/', 'lastmod': '2022-12-19T16:20:29+05:30', 'changefreq': 'weekly'}]}}

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,separators=["\n\n", "\n", ".", "!", "?", ",", " ", ""],chunk_overlap=200,)
doc_chunks = []
for page in pages:
    chunks = text_splitter.split_text(page['text'])
    for i, chunk in enumerate(chunks):
            doc = Document(
                page_content=chunk,
                metadata={"source": page['source']},
            )
            doc_chunks.append(doc)
    print(f"Split {page['source']} into {len(chunks)} chunks")
# Out:
# Split https://vetic.in/ into 10 chunks
# Split https://vetic.in/clinics/gurgaon/sector-57 into 5 chunks
# Split https://vetic.in/clinics/gurgaon into 9 chunks
# Split https://vetic.in/clinics/gurgaon/golf-course-road into 5 chunks
# Split https://vetic.in/clinics/gurgaon/sector-45 into 5 chunks
# Split https://vetic.in/clinics/gurgaon/sohna-road into 5 chunks
# Split https://vetic.in/clinics/noida/sector-49 into 5 chunks
# Split https://vetic.in/clinics/delhi/sector-11 into 5 chunks
# Split https://vetic.in/our-services into 8 chunks
# Split https://vetic.in/urgent-care into 8 chunks
# Split https://vetic.in/blog/tag/pets/ into 6 chunks
# Split https://vetic.in/blog/tag/grooming/ into 4 chunks
# Split https://vetic.in/blog/category/pet-parents/ into 7 chunks
# Split https://vetic.in/blog/category/pet-health/ into 8 chunks
# Split https://vetic.in/blog/category/pet-care/ into 8 chunks
# Split https://vetic.in/blog/contact-me/ into 3 chunks
# Split https://vetic.in/blog/social-icons/ into 3 chunks
# Split https://vetic.in/blog/galleries/ into 3 chunks
# Split https://vetic.in/blog/home/ into 3 chunks

# %%
print(len(doc_chunks))
# Out:
# 2830

# %%
embeddings = OpenAIEmbeddings()

vector_store = Chroma.from_documents(
    doc_chunks,
    embeddings,
    collection_name="vetic",
    persist_directory="src/data/chroma",
)

# Save DB locally
vector_store.persist()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[9], line 11
#       3 vector_store = Chroma.from_documents(
#       4     doc_chunks,
#       5     embeddings,
#       6     collection_name="vetic",
#       7     persist_directory="src/data/chroma",
#       8 )
#      10 # Save DB locally
# ---> 11 vector_store.persist()
#
# File ~/.local/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:340, in Chroma.persist(self)
#     335 if self._persist_directory is None:
#     336     raise ValueError(
#     337         "You must specify a persist_directory on"
#     338         "creation to persist the collection."
#     339     )
# --> 340 self._client.persist()
#
# File ~/.local/lib/python3.10/site-packages/chromadb/api/local.py:522, in LocalAPI.persist(self)
#     515 def persist(self) -> bool:
#     516     """Persist the database to disk.
#     517
#     518     Returns:
#     519         True if the database was persisted successfully
#     520
#     521     """
# --> 522     self._db.persist()
#     523     return True
#
# File ~/.local/lib/python3.10/site-packages/chromadb/db/duckdb.py:437, in PersistentDuckDB.persist(self)
#     434 if self._conn.query("SELECT COUNT() FROM embeddings") == 0:
#     435     return
# --> 437 self._conn.execute(
#     438     f"""
#     439     COPY
#     440         (SELECT * FROM embeddings)
#     441     TO '{self._save_folder}/chroma-embeddings.parquet'
#     442         (FORMAT PARQUET);
#     443 """
#     444 )
#     446 self._conn.execute(
#     447     f"""
#     448     COPY
#    (...)
#     452 """
#     453 )
#
# IOException: IO Error: Could not set lock on file "src/data/chroma/chroma-embeddings.parquet.tmp": Resource temporarily unavailable

# %%
def get_open_ai_model(model_name,temperature = 0, openai_api_key = os.getenv("OPENAI_API_KEY"),chat_model = True, verbose = False):
    if chat_model:
        return ChatOpenAI(model_name=model_name,temperature=temperature,openai_api_key=openai_api_key,verbose=verbose)
    else:
        return OpenAI(model_name=model_name,temperature=temperature,openai_api_key=openai_api_key,verbose=verbose)
    
def get_vectorstore(collection_name,persist_dir,embedding = None):
    if embedding is None:
        embedding = OpenAIEmbeddings()

    vector_store = Chroma(
        collection_name=collection_name,
        embedding_function=embedding,
        persist_directory=persist_dir,
    )

    return vector_store

def make_conversational_chain(model, vector_store ,memory = None , return_source_documents = True , verbose = False, system_prompt = None):
    if memory is None:    
        memory = ConversationSummaryBufferMemory(llm=model , memory_key="chat_history", return_messages=True,input_key='question', output_key='answer')

    if system_prompt is None:
        chain = ConversationalRetrievalChain.from_llm(
        model, 
        vector_store.as_retriever(), 
        memory=memory,
        return_source_documents=return_source_documents,
        verbose=verbose
        )
        return chain

    chain = ConversationalRetrievalChain.from_llm(
    model, 
    vector_store.as_retriever(), 
    memory=memory,
    return_source_documents=return_source_documents,
    combine_docs_chain_kwargs=dict(prompt=system_prompt),
    verbose=verbose
    )

    return chain

# %%
import gradio as gr
import random
import time

with gr.Blocks() as demo:
    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.Button("Clear")

    model = get_open_ai_model("gpt-3.5-turbo",verbose= True,temperature=0.3)
    vector_store = get_vectorstore("vetic","src/data/chroma")

    system_prompt = PromptTemplate.from_template('''
    You are a customer support guide representing vetic, a reputable online platform known for offering pet healthcare services in India. 
    Your role is to assist customers by providing accurate information, offering helpful recommendations, and guiding them towards the solutions of their issues. 
    Feel free to ask clarifying questions to better understand the customer's needs and preferences. Leverage the provided context to answer the question effectively 
    without generating false or fictional information. Double check your response for accuracy. Your responses should be short and friendly.
    Respond only to the following question using only the context and if you don't know the answer respond with "May I connect you with an expert in this topic to discuss this in detail?":

    Context: {context}
    Question: {question}

    You can also ask questions to gain more insights and lead the customer more accurately. 
    Remember, your expertise and helpfulness are key in assisting customers in making informed choices.'''
    )


    # strict_system_prompt = PromptTemplate.from_template('''
    # Respond to the following question using only the context, and if you don't know the answer, 
    # simply respond accordingly without making up information:

    # Context: {context}
    # Question: {question}

    # You can also ask questions to gather more insights and guide the user more effectively. Remember, your expertise and helpfulness are crucial in assisting users 
    # with their technical concerns and providing them with the best solutions.'''
    # )


    chain = make_conversational_chain(model,vector_store,system_prompt=system_prompt)
    
    def user(user_message, history):
        return "", history + [[user_message, None]]

    def bot(history):
        response = chain({"question": history[-1][0]})
        source = response["source_documents"]
        urls = ""
        print("\n\nSources:\n")
        for document in source:
            print(f"Url: {document.metadata['source']}")
            urls += document.metadata['source']
            urls += "\n"
        bot_message = response["answer"] + "\n" + urls
        history[-1][1] = ""
        for character in bot_message:
            history[-1][1] += character
            time.sleep(0.01)
            yield history

    msg.submit(user, [msg, chatbot], [msg, chatbot], queue=False).then(
        bot, chatbot, chatbot
    )
    # make it so that on clear button new conversation chain is made

    clear.click(lambda: chain.memory.clear() ,  None, chatbot, queue=False)

# %%
demo.queue()
demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
# Running on public URL: https://ef54bcbc0e7d403825.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://ef54bcbc0e7d403825.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Sources:
#
# Url: https://vetic.in/cat-surgeries-delhi
# Url: https://vetic.in/Dr.-Danish-Bhutyal
# Url: https://vetic.in/veterinary-clinic-near-me
# Url: https://vetic.in/pet-emergency-care-near-me
#
#
# Sources:
#
# Url: https://vetic.in/privacy-policy
# Url: https://vetic.in/privacy-policy
# Url: https://vetic.in/privacy-policy
# Url: https://vetic.in/terms-of-service
